# %%
from dotenv import load_dotenv
from agents.messaging_agent import MessagingAgent

# %%
agent = MessagingAgent()

# %%
agent.push("Working again!!")

# %%
import chromadb
DB = 'products_vectorstore'
client = chromadb.PersistentClient(path=DB)

collection = client.get_or_create_collection('products')
from agents.planning_agent import PlanningAgent

# %%
planner = PlanningAgent(collection=collection)
planner.plan()
# Out:
# Opportunity(deal=Deal(product_description="The Refurb Unlocked Samsung Galaxy Z Flip 5 features a foldable design with a stunning 6.7-inch Dynamic AMOLED 2X Infinity Flex Display. Powered by the Qualcomm Snapdragon 8 Gen2 processor, it ensures fast performance whether you're browsing, gaming, or streaming. With 8GB of RAM and 512GB of storage, this phone provides ample space for all your apps and media. Its advanced camera system includes a 10MP front camera and dual 12MP rear cameras, enabling high-quality photo and video capture.", price=300.0, url='https://www.dealnews.com/products/Samsung/Unlocked-Samsung-Galaxy-Z-Flip-5-512-GB-Android-Phone/467494.html?iref=rss-c142'), estimate=906.3749526368945, discount=606.3749526368945)
