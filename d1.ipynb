# %%
# !python3 -m modal setup

# %%
import modal

# %%
from hello import app, hello, hello_europe

# %%
with app.run():
    reply = hello.local()
reply
# Out:
# 'Hello from Catania, Sicily, IT!!'

# %%
with app.run():
    reply = hello.remote()
reply
# Out:
# 'Hello from Ashburn, Virginia, US!!'

# %%
with app.run():
    reply=hello_europe.remote()
reply
# Out:
# 'Hello from Frankfurt am Main, Hesse, DE!!'

# %%
from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result = generate.remote("Life is a mystery, everyone must stand alone, I hear")
result

# %%
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result = price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result

# %%
# !modal deploy -m pricer_service

# %%
pricer = modal.Function.from_name("pricer-service", "price")

# %%
pricer.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
# Out:
# 133.0

# %%
# !modal deploy -m pricer_service1
# Out:
# ⠸ Creating objects.....
# └── ⠋ Creating mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── ⠸ Creating mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── ⠦ Creating mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Building image im-GPgkP2tOoy8TK9l7zmoc86
# ⠹ Creating objects...
# ⠹ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#
# => Step 0: FROM base
# ⠼ Creating objects...
# 🔨 Created mount /Users/soroushav/Desktop/projects/capstone_project_llmMaste
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# ⠴ Creating objects...
# ⠴ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# ⠇ Creating objects...
# Collecting accelerate /Users/soroushav/Desktop/projects/capstone_project_llmMaste
# ⠋ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# ⠋ Creating objects...
# Collecting bitsandbytesUsers/soroushav/Desktop/projects/capstone_project_llmMaste
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.48.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# ⠙ Creating objects...
# Collecting huggingface/Users/soroushav/Desktop/projects/capstone_project_llmMaste
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# ⠙ Creating objects...
# Collecting peft mount /Users/soroushav/Desktop/projects/capstone_project_llmMaste
# ⠙ Creating objects...
# ⠙ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.18.0-py3-none-any.whl.metadata (14 kB)
# ⠹ Creating objects...
# Collecting torchmount /Users/soroushav/Desktop/projects/capstone_project_llmMaste
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# ⠼ Creating objects...
# Collecting transformersUsers/soroushav/Desktop/projects/capstone_project_llmMaste
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# ⠼ Creating objects...
# ⠼ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Collecting numpy>=1.17 (from accelerate)
# ⠙ Creating objects...
# ⠙ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# ⠹ Creating objects...
# Collecting packaging>=20.0 (from accelerate)op/projects/capstone_project_llmMaste
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ⠹ Creating objects...
# Collecting psutil (from accelerate)hav/Desktop/projects/capstone_project_llmMaste
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# ⠸ Creating objects...
# ⠼ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Collecting pyyaml (from accelerate)
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# ⠼ Creating objects...
# Collecting huggingface_hub>=0.21.0 (from accelerate)cts/capstone_project_llmMaste
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-1.1.5-py3-none-any.whl.metadata (13 kB)
# ⠴ Creating objects...
# ⠧ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Collecting safetensors>=0.4.3 (from accelerate)
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# ⠏ Creating objects...
# Collecting filelock (from torch)oushav/Desktop/projects/capstone_project_llmMaste
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# ⠏ Creating objects...
# Collecting typing-extensions>=4.10.0 (from torch)ojects/capstone_project_llmMaste
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/typing-extensions/typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ⠏ Creating objects...
# ⠋ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Collecting setuptools (from torch)
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/setuptools/setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ⠹ Creating objects...
# Collecting sympy>=1.13.3 (from torch)v/Desktop/projects/capstone_project_llmMaste
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ⠹ Creating objects...
# Collecting networkx>=2.5.1 (from torch)Desktop/projects/capstone_project_llmMaste
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# ⠸ Creating objects...
# Collecting jinja2 (from torch)oroushav/Desktop/projects/capstone_project_llmMaste
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ⠸ Creating objects...
# ⠼ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Collecting fsspec>=0.8.5 (from torch)
# ⠴ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# ⠴ Creating objects...
# ⠧ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch)
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# ⠧ Creating objects...
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch)apstone_project_llmMaste
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ⠧ Creating objects...
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch)/capstone_project_llmMaste
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ⠏ Creating objects...
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch)cts/capstone_project_llmMaste
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# ⠏ Creating objects...
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch)cts/capstone_project_llmMaste
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# ⠏ Creating objects...
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch)cts/capstone_project_llmMaste
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ⠏ Creating objects...
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch)ts/capstone_project_llmMaste
# ⠏ Creating objects...
# ⠋ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# ⠙ Creating objects...
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch)/capstone_project_llmMaste
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# ⠙ Creating objects...
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch)/capstone_project_llmMaste
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# ⠙ Creating objects...
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch)ts/capstone_project_llmMaste
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# ⠙ Creating objects...
# Collecting nvidia-nccl-cu12==2.27.5 (from torch)rojects/capstone_project_llmMaste
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# ⠙ Creating objects...
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch)ects/capstone_project_llmMaste
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvshmem-cu12/nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# ⠹ Creating objects...
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch)ojects/capstone_project_llmMaste
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# ⠹ Creating objects...
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch)s/capstone_project_llmMaste
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# ⠹ Creating objects...
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch)cts/capstone_project_llmMaste
# ⠹ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# ⠹ Creating objects...
# Collecting triton==3.5.1 (from torch)v/Desktop/projects/capstone_project_llmMaste
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# ⠸ Creating objects...
# ⠸ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Collecting tqdm (from peft)
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ⠼ Creating objects...
# Collecting huggingface_hub>=0.21.0 (from accelerate)cts/capstone_project_llmMaste
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# ⠼ Creating objects...
# ⠦ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Collecting regex!=2019.12.17 (from transformers)
# ⠹ Creating objects...
# ⠸ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# ⠸ Creating objects...
# Collecting requests (from transformers)Desktop/projects/capstone_project_llmMaste
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ⠸ Creating objects...
# ⠦ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
# ⠧ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# ⠇ Creating objects...
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface_hub>=0.21.0->accelerate)lmMaste
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# ⠏ Creating objects...
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)apstone_project_llmMaste
# ⠏ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ⠏ Creating objects...
# ⠏ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
# ⠙ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# ⠙ Creating objects...
# Collecting charset_normalizer<4,>=2 (from requests->transformers)project_llmMaste
# ⠹ Creating objects...
# ⠹ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# ⠸ Creating objects...
# Collecting idna<4,>=2.5 (from requests->transformers)ts/capstone_project_llmMaste
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/idna/idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ⠸ Creating objects...
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)stone_project_llmMaste
# ⠸ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# ⠼ Creating objects...
# Collecting certifi>=2017.4.17 (from requests->transformers)stone_project_llmMaste
# ⠼ Creating objects...
#   Downloading http://pypi-mirror.modal.local:5555/simple/certifi/certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.12.0-py3-none-any.whl (380 kB)
# ⠼ Creating objects...
# ⠴ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.48.2-py3-none-manylinux_2_24_x86_64.whl (59.4 MB)
# ⠴ Creating objects...
# ⠏ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 147.5 MB/s eta 0:00:00
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (899.7 MB)
# ⠙ Creating objects...
# ⠹ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 148.5 MB/s eta 0:00:00
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
# ⠦ Creating objects...
# ⠇ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 132.7 MB/s eta 0:00:00
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
# ⠹ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 163.2 MB/s eta 0:00:00te
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
# ⠹ Creating objects...
# ⠦ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 153.3 MB/s eta 0:00:00
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
# ⠙ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 162.2 MB/s eta 0:00:00e
# ⠙ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
# ⠙ Creating objects...
# ⠹ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 159.6 MB/s eta 0:00:00
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
# ⠋ Creating objects...
# ⠹ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 156.7 MB/s eta 0:00:00
# ⠼ Creating objects...
# ⠴ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
# ⠦ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 177.0 MB/s eta 0:00:00aste
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
# ⠦ Creating objects...
# ⠇ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 163.7 MB/s eta 0:00:00
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
# ⠙ Creating objects...
# ⠹ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 165.2 MB/s eta 0:00:00
# ⠋ Creating objects...
# ⠙ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
# ⠙ Creating objects...
# ⠼ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 150.7 MB/s eta 0:00:00
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
# ⠦ Creating objects...
# ⠦ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 163.6 MB/s eta 0:00:00
# ⠦ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
# ⠧ Creating objects...
# ⠏ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 124.6 MB/s eta 0:00:00
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
# ⠏ Creating objects...
# ⠋ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 128.4 MB/s eta 0:00:00
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvshmem-cu12/nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
# ⠸ Creating objects...
# ⠼ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 161.5 MB/s eta 0:00:00
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# ⠹ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.5 MB)
# ⠹ Creating objects...
# ⠸ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 155.4 MB/s eta 0:00:00
# ⠦ Creating objects...
# ⠦ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.18.0-py3-none-any.whl (556 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 556.4/556.4 kB 183.8 MB/s eta 0:00:00
# ⠧ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.57.1-py3-none-any.whl (12.0 MB)
# ⠧ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 77.3 MB/s eta 0:00:00ste
# ⠇ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# ⠏ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 231.8 MB/s eta 0:00:00e
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# ⠏ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 120.2 MB/s eta 0:00:00aste
# ⠏ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# ⠏ Creating objects...
# ⠏ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 192.4 MB/s eta 0:00:00
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.10.0-py3-none-any.whl (200 kB)
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
# ⠋ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 157.3 MB/s eta 0:00:00aste
# ⠋ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# ⠋ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 152.8 MB/s eta 0:00:00te
# ⠙ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# ⠙ Creating objects...
# ⠹ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (807 kB)
# ⠸ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 168.1 MB/s eta 0:00:00e
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (803 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.5/803.5 kB 227.9 MB/s eta 0:00:00
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# ⠸ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# ⠸ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 172.5 MB/s eta 0:00:00aste
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 356.1 MB/s eta 0:00:00
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/typing-extensions/typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.20.0-py3-none-any.whl (16 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (263 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.5-py3-none-any.whl (64 kB)
# ⠼ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/idna/idna-3.11-py3-none-any.whl (71 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.5.0-py3-none-any.whl (129 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/certifi/certifi-2025.11.12-py3-none-any.whl (159 kB)
# ⠴ Creating objects...
# Downloading http://pypi-mirror.modal.local:5555/simple/setuptools/setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# ⠴ Creating objects...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 145.2 MB/s eta 0:00:00aste
# ⠴ Creating objects...
# ⠴ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, huggingface, urllib3, typing-extensions, triton, tqdm, sympy, setuptools, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, idna, hf-xet, fsspec, filelock, charset_normalizer, certifi, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface_hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# ⠦ Creating objects...
# ⠧ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
# ...
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#
# ⠦ Creating objects...
# Successfully installed MarkupSafe-3.0.3 accelerate-1.12.0 bitsandbytes-0.48.2 certifi-2025.11.12 charset_normalizer-3.4.4 filelock-3.20.0 fsspec-2025.10.0 hf-xet-1.2.0 huggingface-0.0.1 huggingface_hub-0.36.0 idna-3.11 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.3.5 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 packaging-25.0 peft-0.18.0 psutil-7.1.3 pyyaml-6.0.3 regex-2025.11.3 requests-2.32.5 safetensors-0.7.0 setuptools-80.9.0 sympy-1.14.0 tokenizers-0.22.1 torch-2.9.1 tqdm-4.67.1 transformers-4.57.1 triton-3.5.1 typing-extensions-4.15.0 urllib3-2.5.0
# ⠧ Creating objects...
# 🔨 Created mount /Users/soroushav/Desktop/projects/capstone_project_llmMaste
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ⠧ Creating objects...
# ⠇ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Saving image...
# ⠧ Creating objects...
# ⠋ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/7.4 GB 0:00:00
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/7.4 GB 0:00:00
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/7.4 GB 0:00:00
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/7.4 GB 0:00:00
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/7.4 GB 0:00:01
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.6/7.4 GB 0:00:01
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.7/7.4 GB 0:00:01
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.9/7.4 GB 0:00:01
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/7.4 GB 0:00:02
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/7.4 GB 0:00:02
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━ 2.5/7.4 GB 0:00:02
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━ 2.5/7.4 GB 0:00:02
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━ 2.8/7.4 GB 0:00:03
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 3.2/7.4 GB 0:00:03
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━ 3.6/7.4 GB 0:00:03
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━ 4.0/7.4 GB 0:00:03
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 4.9/7.4 GB 0:00:04
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 5.0/7.4 GB 0:00:04
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━ 5.0/7.4 GB 0:00:04
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━ 5.5/7.4 GB 0:00:04
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━ 5.5/7.4 GB 0:00:05
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━ 5.5/7.4 GB 0:00:05
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 6.3/7.4 GB 0:00:05
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 6.3/7.4 GB 0:00:05
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 6.3/7.4 GB 0:00:06
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 6.3/7.4 GB 0:00:06
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 6.3/7.4 GB 0:00:06
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 6.3/7.4 GB 0:00:06
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 7.4/7.4 GB 0:00:07
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 7.4/7.4 GB 0:00:07
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Uploading image snapshot… ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 7.4/7.4 GB 0:00:07
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Image saved, took 12.98s
# ⠦ Creating objects...
# ⠧ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#
# Built image im-GPgkP2tOoy8TK9l7zmoc86 in 132.36s
#
#
# ⠇ Creating objects...
# ⠋ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠸ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠏ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠹ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠴ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Building image im-OA2Dr1EdR2OVAWdFKNSrkX
# ⠴ Creating objects...
# ⠇ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
#
# => Step 0: FROM base
# ⠹ Creating objects...
# 🔨 Created mount /Users/soroushav/Desktop/projects/capstone_project_llmMaste
# => Step 1: ENV HF_HUB_CACHE=/cache
# ⠸ Creating objects...
# ⠴ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠇ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠙ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Saving image...
# ⠏ Creating objects...
# ⠋ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠼ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠧ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠋ Creating objects...
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# Image saved, took 1.00s
# ⠹ Creating objects...
# 🔨 Created mount /Users/soroushav/Desktop/projects/capstone_project_llmMaste
# Built image im-OA2Dr1EdR2OVAWdFKNSrkX in 2.91s
#
#
# ⠹ Creating objects...
# ⠸ Creating objects...ers/soroushav/Desktop/projects/capstone_project_llmMaste
# └── 🔨 Created mount
#     /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# ⠦ Creating objects...
# ├── 🔨 Created mount
# │   /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# │   1.py
# ⠋ Creating objects...
# ├── 🔨 Created mount
# │   /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# │   1.py
# ⠋ Creating objects...
# ├── 🔨 Created mount
# │   /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# │   1.py
# └── 🔨 Created function Pricer.*.
# ✓ Created objects.
# ├── 🔨 Created mount
# │   /Users/soroushav/Desktop/projects/capstone_project_llmMastery/pricer_service
# │   1.py
# └── 🔨 Created function Pricer.*.
# ✓ App deployed in 140.676s! 🎉
#
# View Deployment: https://modal.com/apps/soroushav85/main/deployed/pricer-service

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# 133.0
