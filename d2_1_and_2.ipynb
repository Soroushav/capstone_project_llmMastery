# %%
import os
import re
import math
import json
from tqdm import tqdm
import random
from dotenv import load_dotenv
from huggingface_hub import login
import numpy as np
import pickle
from sentence_transformers import SentenceTransformer
from datasets import load_dataset
import chromadb
from sklearn.manifold import TSNE
import plotly.graph_objects as go

# %%
MAXIMUM_DATAPOINTS = 30_000

# %%
DB = "products_vectorstore"

client = chromadb.PersistentClient(path=DB)

# %%
collection = client.get_or_create_collection('products')

# %%
CATEGORIES = ['Appliances', 'Automotive', 'Cell_Phones_and_Accessories', 'Electronics','Musical_Instruments', 'Office_Products', 'Tools_and_Home_Improvement', 'Toys_and_Games']
COLORS = ['red', 'blue', 'brown', 'orange', 'yellow', 'green' , 'purple', 'cyan']

# %%
# Prework
result = collection.get(include=['embeddings', 'documents', 'metadatas'], limit=MAXIMUM_DATAPOINTS)
vectors = np.array(result['embeddings'])
documents = result['documents']
categories = [metadata['category'] for metadata in result['metadatas']]
colors = [COLORS[CATEGORIES.index(c)] for c in categories]

# %%
# Let's try a 2D chart

tsne = TSNE(n_components=2, random_state=42, n_jobs=-1)
reduced_vectors = tsne.fit_transform(vectors)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 # Let's try a 2D chart
#       3 tsne = TSNE(n_components=2, random_state=42, n_jobs=-1)
# ----> 4 reduced_vectors = tsne.fit_transform(vectors)
#
# File ~/Desktop/projects/capstone_project_llmMastery/venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/Desktop/projects/capstone_project_llmMastery/venv/lib/python3.12/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/projects/capstone_project_llmMastery/venv/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1144, in TSNE.fit_transform(self, X, y)
#    1123 """Fit X into an embedded space and return that transformed output.
#    1124
#    1125 Parameters
#    (...)   1141     Embedding of the training data in low-dimensional space.
#    1142 """
#    1143 self._check_params_vs_input(X)
# -> 1144 embedding = self._fit(X)
#    1145 self.embedding_ = embedding
#    1146 return self.embedding_
#
# File ~/Desktop/projects/capstone_project_llmMastery/venv/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1034, in TSNE._fit(self, X, skip_num_points)
#    1028 # Degrees of freedom of the Student's t-distribution. The suggestion
#    1029 # degrees_of_freedom = n_components - 1 comes from
#    1030 # "Learning a Parametric Embedding by Preserving Local Structure"
#    1031 # Laurens van der Maaten, 2009.
#    1032 degrees_of_freedom = max(self.n_components - 1, 1)
# -> 1034 return self._tsne(
#    1035     P,
#    1036     degrees_of_freedom,
#    1037     n_samples,
#    1038     X_embedded=X_embedded,
#    1039     neighbors=neighbors_nn,
#    1040     skip_num_points=skip_num_points,
#    1041 )
#
# File ~/Desktop/projects/capstone_project_llmMastery/venv/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1086, in TSNE._tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#    1083 # Learning schedule (part 1): do 250 iteration with lower momentum but
#    1084 # higher learning rate controlled via the early exaggeration parameter
#    1085 P *= self.early_exaggeration
# -> 1086 params, kl_divergence, it = _gradient_descent(obj_func, params, **opt_args)
#    1087 if self.verbose:
#    1088     print(
#    1089         "[t-SNE] KL divergence after %d iterations with early exaggeration: %f"
#    1090         % (it + 1, kl_divergence)
#    1091     )
#
# File ~/Desktop/projects/capstone_project_llmMastery/venv/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:400, in _gradient_descent(objective, p0, it, max_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     397 # only compute the error when needed
#     398 kwargs["compute_error"] = check_convergence or i == max_iter - 1
# --> 400 error, grad = objective(p, *args, **kwargs)
#     402 inc = update * grad < 0.0
#     403 dec = np.invert(inc)
#
# File ~/Desktop/projects/capstone_project_llmMastery/venv/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:281, in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose, compute_error, num_threads)
#     278 indptr = P.indptr.astype(np.int64, copy=False)
#     280 grad = np.zeros(X_embedded.shape, dtype=np.float32)
# --> 281 error = _barnes_hut_tsne.gradient(
#     282     val_P,
#     283     X_embedded,
#     284     neighbors,
#     285     indptr,
#     286     grad,
#     287     angle,
#     288     n_components,
#     289     verbose,
#     290     dof=degrees_of_freedom,
#     291     compute_error=compute_error,
#     292     num_threads=num_threads,
#     293 )
#     294 c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
#     295 grad = grad.ravel()
#
# KeyboardInterrupt:

# %%
# Create the 2D scatter plot
fig = go.Figure(data=[go.Scatter(
    x=reduced_vectors[:, 0],
    y=reduced_vectors[:, 1],
    mode='markers',
    marker=dict(size=3, color=colors, opacity=0.7),
)])

fig.update_layout(
    title='2D Chroma Vectorstore Visualization',
    scene=dict(xaxis_title='x', yaxis_title='y'),
    width=1200,
    height=800,
    margin=dict(r=20, b=10, l=10, t=40)
)

fig.show()

# %%
# Let's try 3D!

tsne = TSNE(n_components=3, random_state=42, n_jobs=-1)
reduced_vectors = tsne.fit_transform(vectors)

# %%
# Create the 3D scatter plot
fig = go.Figure(data=[go.Scatter3d(
    x=reduced_vectors[:, 0],
    y=reduced_vectors[:, 1],
    z=reduced_vectors[:, 2],
    mode='markers',
    marker=dict(size=3, color=colors, opacity=0.7),
)])

fig.update_layout(
    title='3D Chroma Vector Store Visualization',
    scene=dict(xaxis_title='x', yaxis_title='y', zaxis_title='z'),
    width=1200,
    height=800,
    margin=dict(r=20, b=10, l=10, t=40)
)

fig.show()
